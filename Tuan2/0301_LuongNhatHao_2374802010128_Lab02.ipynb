# %%
import pandas as pd #Lương Nhật Hào - 2374802010128
import numpy as np

# %% [markdown]
# Tải dữ liệu xét tuyển đại học

# %%
dftuyensinh = pd.read_csv('processed_dulieuxettuyendaihoc.csv',delimiter=",")
dftuyensinh.head()
# Out:
#    STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 0    1  7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  7.00  7.54  7.01
# 1    2  5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...  4.69  5.47  5.07
# 2    3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  5.77  5.38  6.04
# 3    4  6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  6.21  5.20  6.88
# 4    5  6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...  6.50  6.36  6.99
#
#    XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# 0    K    K    K    2.800    3.016    2.804   0.0
# 1    Y   TB   TB    1.876    2.188    2.028   0.0
# 2   TB   TB   TB    2.308    2.152    2.416   1.0
# 3   TB   TB    K    2.484    2.080    2.752   0.0
# 4    K   TB    K    2.600    2.544    2.796   0.0
#
# [5 rows x 66 columns]

# %% [markdown]
# Phần 1: Thống kê dữ liệu

# %% [markdown]
# 1. Hãy sắp xếp dữ liệu điểm DH1 theo thứ tự tăng dần

# %%
dftuyensinh.sort_values(by=['DH1'])
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 53   54  4.9  5.9  6.2  5.6  5.9  5.0  7.0  5.6  6.1  ...  5.69  6.26  6.02
# 43   44  6.6  7.2  5.9  6.9  7.6  8.1  7.3  6.7  6.3  ...  7.05  6.61  6.77
# 5     6  9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  ...  7.96  8.54  7.38
# 72   73  5.5  6.6  7.2  7.6  5.5  6.7  6.7  5.2  6.0  ...  6.20  5.88  6.22
# 83   84  5.9  5.7  7.1  6.7  6.5  8.0  8.1  4.3  7.4  ...  6.47  7.11  7.47
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 6     7  2.8  3.9  5.5  6.9  5.0  7.3  4.6  5.2  4.4  ...  4.90  5.60  6.01
# 11   12  7.9  7.0  9.1  8.6  6.1  7.0  5.6  9.0  8.2  ...  7.43  7.72  7.49
# 23   24  5.3  6.3  5.7  6.9  5.9  7.5  6.6  5.1  6.4  ...  6.05  6.32  6.71
# 24   25  2.4  4.1  3.6  5.5  5.9  5.6  4.9  4.2  3.3  ...  4.45  4.88  5.41
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  7.05  7.84  7.67
#
#     XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# ...

# %% [markdown]
# 2. Hãy sắp xếp dữ liệu điểm DH2 tăng dần theo nhóm giới tính

# %%
dftuyensinh.sort_values(by=['GT','DH2'])
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 95   96  8.6  6.9  7.4  8.8  7.6  5.8  7.3  5.7  8.9  ...  7.43  7.42  6.83
# 25   26  3.6  5.8  6.9  6.1  5.5  7.2  5.5  4.3  4.2  ...  5.40  5.20  5.09
# 24   25  2.4  4.1  3.6  5.5  5.9  5.6  4.9  4.2  3.3  ...  4.45  4.88  5.41
# 46   47  6.7  6.8  6.4  5.9  5.6  6.4  8.0  6.8  6.6  ...  6.49  6.51  6.16
# 13   14  4.9  5.4  5.0  5.0  5.8  7.0  4.2  5.8  4.5  ...  5.38  5.51  6.26
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 68   69  7.3  6.4  6.9  7.5  6.2  8.4  7.6  8.1  8.1  ...  7.19  7.70  8.00
# 11   12  7.9  7.0  9.1  8.6  6.1  7.0  5.6  9.0  8.2  ...  7.43  7.72  7.49
# 47   48  7.9  7.6  8.4  8.6  6.2  7.5  8.7  7.7  7.3  ...  7.67  7.49  7.11
# 2     3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  5.77  5.38  6.04
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  7.05  7.84  7.67
#
#     XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# ...

# %% [markdown]
# 3. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1, Q2 và Q3 của DH1 theo KT

# %%
def get_mean(scroes):
  return sum(scores)/len(scores)

# %%
result = dftuyensinh["DH1"].sum()
print("The result of applying the function on the dataframe:")
print(result)
# Out:
# The result of applying the function on the dataframe:
# 374.0

# %%
def Q1(g):
  return np.percentile(g,25)

# %%
def Q2(g):
  return np.percentile(g,50)

# %%
def Q3(g):
  return np.percentile(g,75)

# %%
def std(g):
  return np.std(g)

# %%
pd.pivot_table(dftuyensinh,values='DH1',index='KT',aggfunc=['count','sum','mean','median','min','max',std,Q1,Q2,Q3])
# Out:
#    count     sum      mean median   min   max       std      Q1    Q2     Q3
#      DH1     DH1       DH1    DH1   DH1   DH1       DH1     DH1   DH1    DH1
# KT
# A     49  163.50  3.336735   3.25  1.00  6.50  1.261226  2.2500  3.25  4.250
# A1     6   17.50  2.916667   3.00  2.00  4.25  0.786165  2.1875  3.00  3.250
# B      9   29.50  3.277778   3.50  1.75  4.50  0.776785  3.2500  3.50  3.750
# C     14   79.25  5.660714   5.25  4.75  7.00  0.782665  5.0625  5.25  6.375
# D1    22   84.25  3.829545   3.75  1.25  6.75  1.338644  3.0000  3.75  4.875

# %% [markdown]
# 4. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median,min, max, std, Q1, Q2 và Q3 của DH1 theo KT và KV

# %%
pd.pivot_table(dftuyensinh,values='DH1',index=['KT','KV'],aggfunc=['count','sum','mean','median','min','max',std,Q1,Q2,Q3])
# Out:
#        count    sum      mean median   min   max       std      Q1     Q2  \
#          DH1    DH1       DH1    DH1   DH1   DH1       DH1     DH1    DH1
# KT KV
# A  1      29  93.75  3.232759  3.250  1.00  6.50  1.345380  2.0000  3.250
#    2       9  31.75  3.527778  3.500  2.00  6.25  1.346005  2.2500  3.500
#    2NT    11  38.00  3.454545  3.500  2.00  4.75  0.871377  2.8750  3.500
# A1 1       2   4.75  2.375000  2.375  2.00  2.75  0.375000  2.1875  2.375
#    2NT     4  12.75  3.187500  3.250  2.00  4.25  0.797947  2.9375  3.250
# B  1       8  25.75  3.218750  3.375  1.75  4.50  0.804650  3.0000  3.375
#    2NT     1   3.75  3.750000  3.750  3.75  3.75  0.000000  3.7500  3.750
# C  1       8  43.50  5.437500  5.250  4.75  7.00  0.681795  5.0000  5.250
#    2       2  11.50  5.750000  5.750  5.00  6.50  0.750000  5.3750  5.750
#    2NT     4  24.25  6.062500  6.000  5.25  7.00  0.817294  5.2500  6.000
# D1 1      13  46.75  3.596154  3.500  1.50  5.75  1.215044  2.7500  3.500
# ...

# %% [markdown]
# 5. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1, Q2 và Q3 của DH1 theo KT, KV và DT

# %% [markdown]
# Phần 2: Trình bày dữ liệu

# %% [markdown]
# 1. Hãy trình bày dữ liệu biến: GT
# Gợi ý
# - Lập bảng tần số và tần suất
# - Vẽ biểu đồ tần số (cột), biểu đồ tần suất (tròn).

# %%
gt = dftuyensinh.groupby("GT")["GT"].agg("count")

# %%
gt.plot.bar()
# Out:
# <Axes: xlabel='GT'>

# %%
gt.plot.pie()
# Out:
# <Axes: ylabel='GT'>

# %%
gt.plot.area(alpha=0.5)
# Out:
# <Axes: xlabel='GT'>

# %% [markdown]
# 2. Hãy trình bày dữ liệu lần lượt các biến: US_TBM1, US_TBM2 và US_TBM3

# %%
cau22 =pd.DataFrame(dftuyensinh, columns=["US_TBM1","US_TBM2","US_TBM3"])

# %%
cau22.describe()
# Out:
#           US_TBM1     US_TBM2    US_TBM3
# count  100.000000  100.000000  100.00000
# mean     2.434480    2.559600    2.67176
# std      0.391203    0.377656    0.29981
# min      1.616000    1.768000    1.91600
# 25%      2.107000    2.223000    2.47300
# 50%      2.480000    2.588000    2.70600
# 75%      2.724000    2.893000    2.87400
# max      3.232000    3.416000    3.31600

# %% [markdown]
# 3. Hãy trình bày dữ liệu biến DT với các học sinh là nam

# %%
cau23 = dftuyensinh[dftuyensinh['GT'] == 'M'].groupby('DT')['DT'].agg('count')
print(cau23)
# Out:
# DT
# 0.0    50
# 1.0     1
# 6.0     1
# Name: DT, dtype: int64

# %% [markdown]
# 4. Hãy trình bày dữ liệu biến KV với các học sinh là nam thuộc dân tộc Kinh, có điểm thỏa
# mãn điều kiện (DH1 >= 5.0 và DH2 >= 4.0 và DH3 >= 4.0)

# %%
dk_gt = (dftuyensinh['GT'] == 'M')
dk_dt = (dftuyensinh['DT'] == 0)
dk_diem = (dftuyensinh['DH1'] >= 5.0) & (dftuyensinh['DH2'] >= 4.0) & (dftuyensinh['DH3'] >= 4.0)
df_loc = dftuyensinh[dk_gt & dk_dt & dk_diem]
cau24 = df_loc.groupby('KV')['KV'].agg('count')
print(cau24)
# Out:
# KV
# 1      2
# 2      2
# 2NT    2
# Name: KV, dtype: int64

# %% [markdown]
# 5. Hãy trình bày dữ liệu lần lượt các biến DH1, DH2, DH3 lớn hơn bằng 5.0 và thuộc khu vực 2NT

# %%
dk_kv = (dftuyensinh['KV'] == '2NT')
dk_dh1 = (dftuyensinh['DH1'] >= 5.0)
dk_dh2 = (dftuyensinh['DH2'] >= 5.0)
dk_dh3 = (dftuyensinh['DH3'] >= 5.0)
df_loc = dftuyensinh[dk_kv & dk_dh1 & dk_dh2 & dk_dh3]
cau25 = df_loc.groupby(['DH1', 'DH2', 'DH3'])['GT'].agg('count')
print(cau25)
# Out:
# DH1   DH2   DH3
# 6.75  5.25  5.0    1
# Name: GT, dtype: int64

# %% [markdown]
# Phần 3: Trực quan hóa dữ liệu theo nhóm phân loại

# %% [markdown]
# 1. Trực quan dữ liệu học sinh nữ trên các nhóm XL1, XL2, XL3 dạng unstacked
# Gợi ý
# - Lọc dữ liệu giới tính là nữ
# - Oy: Chiều cao biểu đồ cột thể hiển số lượng học sinh theo xếp loại
# - Màu sắc thể hiện giá trị xếp loại: [Y, TB, K, G, XS]
# - Ox: thể hiện nhóm XL1, XL2 và XL3

# %%
import pandas as pd
import matplotlib.pyplot as plt  # <-- Cần thêm dòng này
df_nu = dftuyensinh[dftuyensinh['GT'] == 'F']
cols = ['XL1', 'XL2', 'XL3']
bang_thong_ke = df_nu[cols].apply(pd.Series.value_counts)
thu_tu_xep_loai = ['Y', 'TB', 'K', 'G', 'XS']
bang_thong_ke = bang_thong_ke.reindex(thu_tu_xep_loai).fillna(0)
print("Bảng số liệu đã xử lý:")
print(bang_thong_ke)
bang_thong_ke.T.plot.bar(figsize=(12, 6))
plt.title('Biểu đồ xếp loại học sinh Nữ qua các năm')
plt.ylabel('Số lượng')
plt.xlabel('Năm học')
plt.show()
# Out:
# Bảng số liệu đã xử lý:
#      XL1   XL2   XL3
# Y    5.0   1.0   0.0
# TB  18.0  15.0  12.0
# K   24.0  30.0  35.0
# G    1.0   2.0   1.0
# XS   0.0   0.0   0.0

# %% [markdown]
# 2. Trực quan dữ liệu KQXT trên nhóm học sinh có khối thi A, A1, B thuộc khu vực 1, 2

# %%
dk_kt = dftuyensinh['KT'].isin(['A', 'A1', 'B'])
dk_kv = dftuyensinh['KV'].isin(['1', '2'])
df_loc = dftuyensinh[dk_kt & dk_kv]
data_kqxt = df_loc.groupby('KQXT')['KQXT'].agg('count')
print(data_kqxt)
plt.figure()
data_kqxt.plot.pie(autopct='%.1f%%', startangle=90, ylabel='')
plt.title("Tỉ lệ KQXT (Khối A,A1,B - KV 1,2)")
plt.show()
plt.figure()
data_kqxt.plot.bar(color=['salmon', 'skyblue'])
plt.title("Số lượng KQXT (Khối A,A1,B - KV 1,2)")
plt.xlabel("Kết quả xét tuyển")
plt.ylabel("Số lượng thí sinh")
plt.xticks(rotation=0)
plt.show()
# Out:
# KQXT
# 0.0    44
# 1.0     4
# Name: KQXT, dtype: int64

# %% [markdown]
# 3. Trực quan dữ liệu số lượng thí sinh từng khu vực dựa trên từng nhóm khối thi

# %%
data_group = dftuyensinh.groupby(['KT', 'KV'])['KT'].agg('count')
data_plot = data_group.unstack()
print(data_plot)
data_plot.plot.bar(stacked=False, figsize=(10, 6))
plt.title("Số lượng thí sinh từng Khu vực theo Khối thi")
plt.xlabel("Khối thi (KT)")
plt.ylabel("Số lượng thí sinh")
plt.legend(title="Khu vực")
plt.xticks(rotation=0)
plt.show()
# Out:
# KV     1    2   2NT
# KT
# A   29.0  9.0  11.0
# A1   2.0  NaN   4.0
# B    8.0  NaN   1.0
# C    8.0  2.0   4.0
# D1  13.0  8.0   1.0

# %% [markdown]
# 4. Trực quan dữ liệu số lượng thí sinh đậu, rớt trên từng nhóm khối thi

# %%
data_kqxt_kt = dftuyensinh.groupby(['KT', 'KQXT'])['KT'].agg('count')
data_plot = data_kqxt_kt.unstack()
print(data_plot)
data_plot.plot.bar(stacked=False, figsize=(10, 6), color=['salmon', 'lightgreen'])
plt.title("Số lượng thí sinh Đậu/Rớt trên từng Khối thi")
plt.xlabel("Khối thi")
plt.ylabel("Số lượng")
plt.legend(["Rớt", "Đậu"], title="Kết quả")
plt.xticks(rotation=0)
plt.show()
# Out:
# KQXT   0.0  1.0
# KT
# A     45.0  4.0
# A1     6.0  NaN
# B      9.0  NaN
# C     10.0  4.0
# D1    20.0  2.0

# %% [markdown]
# 5. Trực quan dữ liệu số lượng thí sinh đậu rớt trên từng nhóm khu vực.

# %%
data_kv_kqxt = dftuyensinh.groupby(['KV', 'KQXT'])['KV'].agg('count')
data_plot = data_kv_kqxt.unstack()
print(data_plot)
data_plot.plot.bar(stacked=False, figsize=(10, 6), color=['salmon', 'mediumseagreen'])
plt.title("Số lượng thí sinh Đậu/Rớt theo từng Khu vực")
plt.xlabel("Khu vực")
plt.ylabel("Số lượng thí sinh")
plt.legend(["Rớt", "Đậu"], title="Kết quả")
plt.xticks(rotation=0)
plt.show()
# Out:
# KQXT  0.0  1.0
# KV
# 1      57    3
# 2      14    5
# 2NT    19    2

# %% [markdown]
# 6. Trực quan dữ liệu số lượng thí sinh đậu rớt dựa trên từng nhóm dân tộc

# %%
data_dt_kqxt = dftuyensinh.groupby(['DT', 'KQXT'])['DT'].agg('count')
data_plot = data_dt_kqxt.unstack()
print(data_plot)
data_plot.plot.bar(stacked=False, figsize=(10, 6), color=['salmon', 'mediumseagreen'])
plt.title("Số lượng thí sinh Đậu/Rớt theo Dân tộc")
plt.xlabel("Dân tộc (Mã DT)")
plt.ylabel("Số lượng thí sinh")
plt.legend(["Rớt", "Đậu"], title="Kết quả")
plt.xticks(rotation=0)
plt.show()
# Out:
# KQXT   0.0   1.0
# DT
# 0.0   87.0  10.0
# 1.0    2.0   NaN
# 6.0    1.0   NaN

# %% [markdown]
# 7. Trực quan dữ liệu số lượng thí sinh đậu rớt dựa trên từng nhóm giới tính.

# %%
data_gt_kqxt = dftuyensinh.groupby(['GT', 'KQXT'])['GT'].agg('count')
data_plot = data_gt_kqxt.unstack()
print(data_plot)
data_plot.plot.bar(stacked=False, figsize=(10, 6), color=['salmon', 'mediumseagreen'])
plt.title("Số lượng thí sinh Đậu/Rớt theo Giới tính")
plt.xlabel("Giới tính")
plt.ylabel("Số lượng thí sinh")
plt.legend(["Rớt", "Đậu"], title="Kết quả")
plt.xticks(rotation=0)
plt.show()
# Out:
# KQXT  0.0  1.0
# GT
# F      45    3
# M      45    7

# %% [markdown]
# Phần 4: Trực quan hóa dữ liệu nâng cao

# %% [markdown]
# 1. Vẽ biểu đồ đường Simple cho biến T1

# %%
dftuyensinh['T1'].plot(title='Biểu đồ đường (Line Plot) cho biến T1', figsize=(10, 6))
plt.ylabel('Điểm T1')
plt.xlabel('Số thứ tự sinh viên')
plt.show()

# %% [markdown]
# 2. Hãy tạo biến phân loại (phanlopt1) cho môn toán (T1) như sau:
# a. Từ 0 đến dưới 5 = kém (ký hiệu “k”)
# b. Từ 5 đến dưới 7 = trung bình (ký hiệu “tb”)
# c. Từ 7 đến dưới 8 = khá (ký hiệu “k”)
# d. Từ 8 trở lên = giỏi (ký hiệu “g”)

# %%
def phan_loai(score):
    if score < 5: return 'kem'
    elif score < 7: return 'tb'
    elif score < 8: return 'kha'
    else: return 'gioi'

dftuyensinh['phanlopt1'] = dftuyensinh['T1'].apply(phan_loai)

# %% [markdown]
# 3. Lập bảng tần số cho biến phanloait1

# %%
print("Bảng tần số phân loại T1:")
print(dftuyensinh['phanlopt1'].value_counts())
# Out:
# Bảng tần số phân loại T1:
# phanlopt1
# tb      46
# kem     23
# kha     19
# gioi    12
# Name: count, dtype: int64

# %% [markdown]
# 4. Vẽ biểu đồ đường Multiple Line cho biến T1 được phân loại bởi biến phanlopt1

# %%
grouped = dftuyensinh.groupby(['T1', 'phanlopt1']).size().unstack(fill_value=0)
plt.figure(figsize=(10, 6))
for col in grouped.columns:
    plt.plot(grouped.index, grouped[col], label=col)

plt.xlabel("T1")
plt.ylabel("Count")
plt.title("Multiple Line cho biến T1 được phân loại bởi biến phanlopt1")
plt.legend(title="PhanlopT1")
plt.grid(True)
plt.show()

# %% [markdown]
# 5. Vẽ biểu đồ Drop-line cho biến T1 được phân loại bởi biến phanlopt1

# %%
fig, ax = plt.subplots(figsize=(10, 6))
colors = ['red', 'blue', 'green', 'orange']
for i, col in enumerate(grouped.columns):
    markerline, stemlines, baseline = ax.stem(grouped.index, grouped[col], label=col)
    color = colors[i % len(colors)]
    plt.setp(stemlines, 'color', color)
    plt.setp(markerline, 'markerfacecolor', color, 'markeredgecolor', color, 'marker', 'o') # 'o' là hình tròn

plt.legend(title='Phân lớp T1')
plt.xlabel('Điểm T1')
plt.ylabel('Số lượng (Count)')
plt.title('Biểu đồ Drop-line cho biến T1 (Chấm tròn)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# Phần 5: Mô tả dữ liệu và khảo sát dạng phân phối

# %% [markdown]
# 1. Hãy mô tả và khảo sát phân phối cho biến T1
# Gợi ý
# BÀI TẬP THỰC HÀNH MÔN NHẬP MÔN PHÂN TÍCH DỮ LIỆU VÀ HỌC SÂU
# 7
# - Mô tả độ tập trung và phân tán của dữ liệu T1
# - Vẽ biểu đồ Box-Plot và xác định các 10 đại lượng trong biểu đồ đó
# - Mô tả hình dáng lệch của phân phối T1 dựa vào các đại lượng hướng tâm
# - Vẽ biểu đồ Histogram biểu thị hình dáng phân phối
# - Mô tả các đặc trưng của phân phối, mức độ lệch và mức độ nhọn
# - Kiểm chứng phân phối chuẩn QQ-Plot
# - Nhận xét và đánh giá về phân phối của T1

# %%
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt


print("\n=== CÂU 1: PHÂN TÍCH BIẾN T1 ===")

desc = dftuyensinh['T1'].describe()
skewness = dftuyensinh['T1'].skew()
kurtosis = dftuyensinh['T1'].kurtosis()

print("Thống kê mô tả:")
print(desc)
print(f"Skewness (Độ lệch): {skewness:.4f}")
print(f"Kurtosis (Độ nhọn): {kurtosis:.4f}")

# 1.2 Vẽ biểu đồ (Box-plot, Histogram, QQ-Plot)
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Box-Plot
sns.boxplot(x=dftuyensinh['T1'], ax=axes[0], color='lightblue')
axes[0].set_title('Box-Plot biến T1')

# Histogram
sns.histplot(dftuyensinh['T1'], kde=True, ax=axes[1], color='green')
axes[1].set_title('Histogram biến T1')

# QQ-Plot (Kiểm tra phân phối chuẩn)
stats.probplot(dftuyensinh['T1'], dist="norm", plot=axes[2])
axes[2].set_title('QQ-Plot biến T1')

plt.tight_layout()
plt.show()

# Nhận xét phân phối
print("\n--- NHẬN XÉT CÂU 1 ---")
if abs(skewness) < 0.5:
    print(f"- Skewness = {skewness:.2f}: Phân phối khá đối xứng (gần chuẩn).")
elif skewness > 0:
    print(f"- Skewness = {skewness:.2f}: Phân phối lệch phải (Positive Skew).")
else:
    print(f"- Skewness = {skewness:.2f}: Phân phối lệch trái (Negative Skew).")
# Out:
# === CÂU 1: PHÂN TÍCH BIẾN T1 ===
# Thống kê mô tả:
# count    100.000000
# mean       5.946000
# std        1.608338
# min        2.400000
# 25%        5.000000
# 50%        5.850000
# 75%        7.200000
# max        9.300000
# Name: T1, dtype: float64
# Skewness (Độ lệch): -0.1782
# Kurtosis (Độ nhọn): -0.4801
# --- NHẬN XÉT CÂU 1 ---
# - Skewness = -0.18: Phân phối khá đối xứng (gần chuẩn).

# %% [markdown]
# 2. Hãy mô tả và khảo sát phân phối cho biến T1 trên từng nhóm phân lớp (phanlopT1)
# Gợi ý
# - Trực quan hóa biểu đồ Box-plot, histogram và QQ-plot theo phân nhóm là giá trị
# của ‘phanlopT1’.

# %%
sns.boxplot(x='phanlopt1', y='T1', data=dftuyensinh,
            order=['kem', 'tb', 'kha', 'gioi'], palette='Set3')
plt.title('Box-Plot T1 phân theo nhóm xếp loại')
plt.show()

# 2.2 Histogram theo phân lớp
g = sns.FacetGrid(dftuyensinh, col="phanlopt1", col_order=['kem', 'tb', 'kha', 'gioi'], col_wrap=2)
g.map(sns.histplot, "T1", kde=True)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Histogram T1 theo từng nhóm')
plt.show()

# 2.3 QQ-Plot theo phân lớp
def qqplot_group(x, **kwargs):
    ax = plt.gca()
    stats.probplot(x, dist="norm", plot=ax)

g = sns.FacetGrid(dftuyensinh, col="phanlopt1", col_order=['kem', 'tb', 'kha', 'gioi'], col_wrap=2)
g.map(qqplot_group, "T1")
plt.subplots_adjust(top=0.9)
g.fig.suptitle('QQ-Plot T1 theo từng nhóm')
plt.show()
# Out:
# /tmp/ipython-input-3130109222.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='phanlopt1', y='T1', data=dftuyensinh,

# %% [markdown]
# 3. Hãy khảo sát tương quan giữa biến DH1 theo biến T1
# Gợi ý
# - Nhận xét giá trị Covariance hoặc Correlation
# - Vẽ biểu đồ Scatter thể hiện liên hệ của biến phụ thuộc DH1 theo biến độc lập T1

# %%
corr_dh1_t1 = dftuyensinh['DH1'].corr(dftuyensinh['T1']) # Hệ số tương quan
cov_dh1_t1 = dftuyensinh['DH1'].cov(dftuyensinh['T1'])   # Hiệp phương sai

print(f"Hệ số tương quan (Correlation): {corr_dh1_t1:.4f}")
print(f"Hiệp phương sai (Covariance): {cov_dh1_t1:.4f}")

# 3.2 Vẽ Scatter Plot kèm đường hồi quy tuyến tính
plt.figure(figsize=(8, 6))
sns.regplot(x='T1', y='DH1', data=dftuyensinh, line_kws={'color': 'red'})
plt.title(f'Biểu đồ Scatter: T1 vs DH1 (r={corr_dh1_t1:.2f})')
plt.xlabel('Điểm T1 (Học bạ)')
plt.ylabel('Điểm DH1 (Điểm thi)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# Hệ số tương quan (Correlation): 0.0493
# Hiệp phương sai (Covariance): 0.1128

# %% [markdown]
# 4. Hãy khảo sát tương quan giữa biến DH1 theo biến T1 trên từng nhóm khu vực

# %%
sns.lmplot(x='T1', y='DH1', hue='KV', data=dftuyensinh, height=6, aspect=1.5)
plt.title('Tương quan T1 và DH1 phân theo Khu vực (KV)')
plt.show()

# %% [markdown]
# 5. Hãy khảo sát tương quan giữa các biến DH1, DH2, DH3
# Gợi ý
# - Nhận xét ma trận hiệp phương sai hoặc ma trận tương quan
# - Vẽ biểu đồ Scatter giữa các biến

# %%
cols = ['DH1', 'DH2', 'DH3']
print("Ma trận tương quan (Correlation Matrix):")
print(dftuyensinh[cols].corr())
print("\nMa trận hiệp phương sai (Covariance Matrix):")
print(dftuyensinh[cols].cov())
sns.pairplot(dftuyensinh[cols])
plt.suptitle('Biểu đồ Pairplot: Quan hệ giữa điểm thi 3 môn', y=1.02)
plt.show()
# Out:
# Ma trận tương quan (Correlation Matrix):
#           DH1       DH2       DH3
# DH1  1.000000  0.035154  0.018731
# DH2  0.035154  1.000000 -0.091523
# DH3  0.018731 -0.091523  1.000000
#
# Ma trận hiệp phương sai (Covariance Matrix):
#           DH1       DH2       DH3
# DH1  2.028939  0.053081  0.027778
# DH2  0.053081  1.123712 -0.101010
# DH3  0.027778 -0.101010  1.083965
